# %%
# Podemos tener
# un comentario
# compuesto por
# varias lineas

# %%
# Toda linea la puedo comentar con la combinacion de teclas CTRL + /

# %%
# Declarar o definir variables
s = 19
c = 56.3
d = "Primera sesion"
e = 'INtroduccion a Python'
b1 = True
b2 = False
cmp1 = 12 + 3.3j

# %%
# Operaciones aritmeticas : / * - + **
# Division entera : D = d * q +r
# q = D // d
# r = D % d

# %%
# Peso de una persona
peso = 104.6

# Estatura de una persona [cm]
estatura = 180.0

# %%
# Bajo la hipotesis de que la variable peso estan en kilos
# Calcular el peso en libras
# Conocimiento basico (Conocimiento real) : 1kg equivale a 2.2libras
peso_lb = peso*2.2

# %%
# Indice de masa corporal
# Conocimiento real : IMC = peso/estatura**2
IMC = peso/(estatura*10**(-2))**2

# Potenciacion : **

# %%
# observar/mostrar el valor almacenado en la variable peso_lb
peso_lb
# Out:
# 230.12

# %%
# Mostrar IMC
IMC
# Out:
# 32.28395061728395

# %%
# Carga del modulo math
import math as m

# %%
# Listado de elementos que el modulo math provee
dir(m)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
# # Lista de elementos de interes del modulo math
# 'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp'

# %%
# Acceso a la documentacion de la funcion pow del modulo math
help(m.pow)
# Out:
# Help on built-in function pow in module math:
#
# pow(x, y, /)
#     Return x**y (x to the power of y).

# %%
m.pow(0.001, -3)
# Out:
# 999999999.9999999

# %%
# Leamos la documentacion de la funcion seno (m.sin)
help(m.sin)
# Out:
# Help on built-in function sin in module math:
#
# sin(x, /)
#     Return the sine of x (measured in radians).

# %%
# Calculemos el seno de 30°
m.sin(30*3.14/180)
# Out:
# 0.4997701026431024

# %%
# error
0.5 - 0.4997701026431024
# Out:
# 0.0002298973568976015

# %%
# Consideremos algunas aproximaciones al valor de PI
pi_1 = 22/7
pi_2 = 355/113
pi_3 = 710/226

seno30_1 = m.sin(30*pi_1/180)
seno30_2 = m.sin(30*pi_2/180)
seno30_3 = m.sin(30*pi_3/180)

# %%
seno30_1
# Out:
# 0.5001825021996698

# %%
seno30_2
# Out:
# 0.5000000385040936

# %%
seno30_3
# Out:
# 0.5000000385040936

# %%
# Constante pi esta proveida por el modulo math
m.pi
# Out:
# 3.141592653589793

# %%
# Calculemos el area del circulo de radio raiz cuadrada de 2
radio = 2**(1/2)
area = m.pi*(radio**2)
area
# Out:
# 6.283185307179588

# %%
(2**(1/2))**2
# Out:
# 2.0000000000000004

# %%
# Definamos un par de variables de naturaleza logica (bool)
x1 = True
x2 = False

# %%
x3 = true
x4 = false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-dc47b0342e15> in <cell line: 0>()
# ----> 1 x3 = true
#       2 x4 = false
#
# NameError: name 'true' is not defined

# %%
# and : y logico
# or : o logico
# not : negacion

x3 = x1 and x2
x4 = not(x2 or x1)
x5 = x3 and (not x4)

# %%
x3
# Out:
# False

# %%
x4
# Out:
# False

# %%
x5
# Out:
# False

# %%
# Definamos 3 variables de tipo cadena de caracter
ch1 = "QUe fea clase la del dia de hoy 17/03/2025"
ch2 = 'Lunes, 17 de marzo del 2025'
ch3 = """Desde que zarpara la barca, Janampa habia pronunciado solo dos o tres palabras,
siempre oscuras, cargadas de reserva, como si se hubiera obstinado en crear un clima de
misterio. Sentado frente a Dionisio, hacia una hora que remaba infatigablemente. Ya las
fogatas de la orilla habian desaparecido y las barcas de los otros Pescadores apenas se
divisaban en lontananza, palidamente iluminadas por sus faroles de aceite. Dionisio trataba
en vano de estudiar las facciones de su companero. Ocupado en desaguar el bote con la
pequena lata, observaba a hurtadillas su rostra que, recibiendo en plena nuca la luz cruda
del farol, solo mostraba una silueta negra e impenetrable. A veces, al ladear ligeramente el
semblante, la luz se le escurria por los pdmulos sudorosos o por el cuello desnudo y se
podia adivinar una faz hosca, decidida, cruelmente poseida de una extraha resolucion. """

# %%
# Una variable como ch1, ch2 o ch3 sean de tipo cadena de caracter
# Debemos de reconocer que una variable de tipo cadena de caracter tiene una naturaleza vectorial

# %%
# Primera componente
ch1[0]
# Out:
# 'Q'

# %%
# Segundo elemento (segundo caracter) : indice 1
ch1[1]
# Out:
# 'U'

# %%
# 10ma componente de ch2
ch2[9]
# Out:
# ' '

# %%
# 15ava componente de ch3
ch3[14]
# Out:
# 'a'

# %%
# Ultima componente (ultimo caracter) de ch3
ch3[-1]
# Out:
# ' '

# %%
# ultima componente de ch1
ch1[-1]
# Out:
# '5'

# %%
# penultima componente de ch1
ch1[-2]
# Out:
# '2'

# %%
# Si leo de izquierda a derecha (desde el inicio hasta el final) : 0,1,2,3,...
# Si leo la cadena de derecha a izquierda (desde el final al inicio): -1, -2 , -3, -4, ...

# %%
# Acceso a porciones de una cadena de caracteres
# los primeros 5 elementos de ch2
ch2[:4+1]
# Out:
# 'Lunes'

# %%
# seleccionemos los primeros 10 caracteres de ch3
ch3[:9+1]
# Out:
# 'Desde que '

# %%
# Accedamos a los ultimos 8 caracteres de ch2
ch2[-8:]
# Out:
# 'del 2025'

# %%
# Accedamos a los ultimos 3 caracteres de ch1
ch1[-3:]
# Out:
# '025'

# %%
# Deseo obtener la subcadena que inicia en el 14avo elemento de ch3
# y llega al 32avo elemento de ch3
ch3[13:31+1]
# Out:
# 'para la barca, Jana'

# %%
# Numero de elementos de una variable de tipo cadena de caracter

# %%
# Numero de elementos de ch3
len(ch3)
# Out:
# 889

# %%
# Numero de elementos de ch1
len(ch1)
# Out:
# 42

# %%
# + : concatena
# + : str x str -> str
# * : repite
# * : int x str -> str
# * : str x int -> str

# %%
msj = "hola" + "mundo"
msj
# Out:
# 'holamundo'

# %%
msj10 = msj*10
msj10
# Out:
# 'holamundoholamundoholamundoholamundoholamundoholamundoholamundoholamundoholamundoholamundo'

# %%
msj2 = 2*msj + 10*msj10
msj2
# Out:
# '...'

# %%
# Modulo string
import string

# %%
# Documentacion del modulo string
help(string)
# Out:
# Help on module string:
#
# NAME
#     string - A collection of string constants.
#
# MODULE REFERENCE
#     https://docs.python.org/3.11/library/string.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Public module variables:
#
#     whitespace -- a string containing all ASCII whitespace
#     ascii_lowercase -- a string containing all ASCII lowercase letters
#     ascii_uppercase -- a string containing all ASCII uppercase letters
#     ascii_letters -- a string containing all ASCII letters
#     digits -- a string containing all ASCII decimal digits
#     hexdigits -- a string containing all ASCII hexadecimal digits
#     octdigits -- a string containing all ASCII octal digits
# ...

# %%
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
# NUmero de elementos de la constante string.ascii_letters
len(string.ascii_letters)
# Out:
# 52

# %%
# letras en minuscula
string.ascii_letters[:25+1]
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
# letras en mayuscula
string.ascii_letters[26:]
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
# Constante digits del modulo string
string.digits
# Out:
# '0123456789'
